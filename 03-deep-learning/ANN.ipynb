# %% [markdown]
# <a href="https://colab.research.google.com/github/GitPots/ML-notes/blob/main/ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 感知机，由一个或多个组织在单层中的TLU组成，多个TLU即为多标签分类器，或者多类分类
#
# (Liner)Threshold Logic Unit
#
# 输入数字
#
# 加权求和:wx+b
#
# 阶跃函数，此处激活函数改为逻辑函数即为逻辑回归或线性SVM
#
# 输出数字
#
# heaviside函数，sgn函数
#
# Hebb规则：两个神经元同时触发，则两者之间的连接权重会增强。对于产生错误预测的输出神经元，会加强来自输入的连接权重，从而有助于正确预测。
